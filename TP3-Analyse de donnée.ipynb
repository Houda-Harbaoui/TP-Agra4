# %% [markdown]
# # Exercice 1:
# #### Question 1:
# - Ecrire une fonction StatSncf qui calcule le nombre de lignes et colonnes  dans le fichier retards-SNCF.csv
# #### Question 2:
# - Afficher tous les voyages Paris Nord-Lille
# - Calculer le nombre de voyages ayant départ Lille effectué en mois de novembre 2011
# - Créer un fichier Atlantique ou copier les voyages ayant axe "atlantique" entre 2014 et 2017
# - Quel est le plus grand nombre de trains programmés? ça correspond à quelle ligne(départ-arrivée)
# - Quel est le plus petit nombre de trains programmés? ça correspond à quelle ligne(départ-arrivée)
# - Calculer la moyenne des trains programmés en 2013
# - Calculer le nombre total des TGVs annulés par SNCF entre 2011 et 2017
# - sur quelle ligne il y a plus de retard ?
# - sur quelle ligne il y a le plus de trains annulés ?
# #### Question 3:
#    1 - Creer un fichier "Planification.csv"
#
#    2 -Copier la colonne les colonnes F,G, H,I dans le fichier "Planification.csv".
#
#    3  - Dans le fichier "Planification.csv" (à créer): rajouter une colonne nommée "Planification" qui prendra 3 attributs:
#     - "Parfaite" si le taux de régularité égal à 100%
#     - "Bonne" si le taux de régularité est situé entre 80 et 90%
#     - "Moyenne" si le taux de régularité est situé entre 60 et 80 %
#     - "Mauvaise" si le taux de régularité est inférieur à 60%

# %% [markdown]
# ##  Exercice 2:
# Créer un fichier csv composé de 4 colonnes:
# - CL1 nommée 'Année'
# - CL2 nommée  'Bissextile'
# - CL3 nommée 'Evenement sportif mondial'
#
# - La première colonne doit être remplie par les années entre 2001 et 2030
#
# Rappel: une année bissextile:
#    - Si une année est divisible par 4, 100 et 400, il s’agit d’une année bissextile.
#    - Si une année est divisible par 4 mais pas par 100, il s’agit d’une année bissextile.
#
# - La deuxième colonne indique si l'année est bissextile ou non
# - LA troisième colonne doit indiquér l'évènement mondial en sport soit:
#     - coupe du monde en Foot sachant  qu'elle est organisée une fois tous les 4 ans
#     - coupe du monde en Handball sachant  qu'elle est réalisée une fois tous les 2 ans
#
#   Remarque:
#        - A partir du 2001  c'est la coupe du monde en Handball
#        -  A partir du 2002 c'est la coupe du monde de Football

# %% [markdown]
# ## Exercice 3
# En se basant sur le fichier cinema.csv, Ecrivez les requêtes python correspondant aux questions suivantes:
#     1. Quel est le film ayant le plus gros succès du box-office mondial (répertorie les films ayant engrangé le plus de recettes au niveau mondial) ?
#     2. Quelle est la saga qui a cumulé le plus de dollars ? Et combien ?
#     3. Pour chaque année, citer les films ayant obtenu la meilleure note
#     4. Citer tous les films produits par Warner Bros entre 1975 et 1990
#     5. Citer tous les films ayant comme genre : war, drama et Biography
#     6. Citer le plus long film et son année de sortie.
